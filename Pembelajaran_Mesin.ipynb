# %% [markdown]
# <a href="https://colab.research.google.com/github/nrlqlby/Pembelajaran-Mesin-B/blob/main/Pembelajaran_Mesin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/unemployment analysis.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
data.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %%
print(data.dtypes)
# Out:
# Country Name     object
# Country Code     object
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#                     Country Name Country Code   1991   1992   1994   1995  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.84   7.83
# 1                    Afghanistan          AFG  10.65  10.82  10.73  11.18
# 2     Africa Western and Central          AFW   4.42   4.53   4.54   4.53
# 3                         Angola          AGO   4.21   4.21   4.16   4.11
# 4                        Albania          ALB  10.31  30.01  20.84  14.61
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   3.04   3.19
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.34   8.96
# 232                 South Africa          ZAF  29.95  29.98  29.89  29.89
# 233                       Zambia          ZMB  18.90  19.37  18.43  16.81
# 234                     Zimbabwe          ZWE   4.94   4.99   4.96   5.63
#
#       1996   1997   1998   1999  ...   2012   2013   2014   2015   2016  \
# ...

# %%
data.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.278000    7.626340    8.070766    8.246043    8.333915    8.494894
# std      6.013749    6.296617    6.335855    6.243778    6.330822    6.358431
# min      0.300000    0.340000    0.410000    0.470000    0.500000    0.560000
# 25%      2.945000    3.140000    3.700000    3.890000    3.945000    3.995000
# 50%      5.410000    5.710000    6.030000    6.550000    6.700000    7.050000
# 75%      9.815000   10.170000   10.895000   11.110000   11.050000   11.405000
# max     36.120000   36.390000   36.740000   36.980000   37.340000   38.800000
#
#              1997        1998        1999        2000  ...        2012  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.394043    8.441064    8.568043    8.438979  ...    8.062553
# ...

# %%
data.loc[:,"2000":].corr()
# Out:
#           2000      2001      2002      2003      2004      2005      2006  \
# 2000  1.000000  0.983833  0.961153  0.955356  0.937861  0.917901  0.895482
# 2001  0.983833  1.000000  0.988930  0.978333  0.961853  0.940258  0.916591
# 2002  0.961153  0.988930  1.000000  0.990016  0.976304  0.954032  0.931697
# 2003  0.955356  0.978333  0.990016  1.000000  0.991522  0.975358  0.954098
# 2004  0.937861  0.961853  0.976304  0.991522  1.000000  0.991478  0.975364
# 2005  0.917901  0.940258  0.954032  0.975358  0.991478  1.000000  0.991408
# 2006  0.895482  0.916591  0.931697  0.954098  0.975364  0.991408  1.000000
# 2007  0.876358  0.896022  0.910564  0.933207  0.953135  0.972651  0.991492
# 2008  0.847708  0.872634  0.889444  0.907951  0.928109  0.943842  0.965823
# 2009  0.842752  0.859996  0.872784  0.894035  0.912995  0.920782  0.928315
# 2010  0.836178  0.855796  0.864939  0.885469  0.904864  0.909909  0.912416
# ...

# %%
# @title 2004 vs 2009

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='2004', y='2009', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Dengan API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-8a56efe7-3fbd-4c7e-8e6f-acdabcc809b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a56efe7-3fbd-4c7e-8e6f-acdabcc809b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "employ"
# Out:
# ...
# ref                                                   title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# pavansubhasht/ibm-hr-analytics-attrition-dataset      IBM HR Analytics Employee Attrition & Performance   50KB  2017-03-31 06:55:16         165409       2405  0.88235295
# tawfikelmetwally/employee-dataset                     Employee dataset                                    19KB  2023-09-06 18:15:55          21583        259  0.9411765
# HRAnalyticRepository/employee-attrition-data          Employee Attrition                                 501KB  2017-04-26 18:39:14          17760        243  0.8235294
# ...

# %%
# !kaggle datasets download pavansubhasht/ibm-hr-analytics-attrition-dataset
# Out:
# ...
#   0% 0.00/50.1k [00:00<?, ?B/s]
# 100% 50.1k/50.1k [00:00<00:00, 64.2MB/s]

# %%
# !unzip /content/ibm-hr-analytics-attrition-dataset.zip
# Out:
# Archive:  /content/ibm-hr-analytics-attrition-dataset.zip
#   inflating: WA_Fn-UseC_-HR-Employee-Attrition.csv

# %%
pd.read_csv('/content/WA_Fn-UseC_-HR-Employee-Attrition.csv')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...
